# %%
import pandas as pd
import json

# %%
# JSON dosyasını oku
with open("20-sohbet-trendyol-mila.json", "r", encoding="utf-8") as f:
    data = json.load(f)

rows = []
for sohbet in data:
    mesaj_listesi = []
    timestamps = []

    for m in sohbet["mesajlar"]:
        sender = "Bot" if m["sender"].lower() == "bot" else "Müşteri"
        mesaj_listesi.append(f"{sender}: {m['text']}")
        timestamps.append(pd.to_datetime(m["timestamp"], format="%d.%m.%Y %H:%M:%S"))

    tum_mesajlar = "\n".join(mesaj_listesi)
    if timestamps:
        ilk_mesaj_tarihi = timestamps[0]
        son_mesaj_tarihi = timestamps[-1]
        fark = son_mesaj_tarihi - ilk_mesaj_tarihi  # timedelta

        # Dakika ve saniye olarak formatla
        total_seconds = int(fark.total_seconds())
        dakika = total_seconds // 60
        saniye = total_seconds % 60
        konusma_suresi = f"{dakika} dk {saniye} sn"
    else:
        ilk_mesaj_tarihi = None
        son_mesaj_tarihi = None
        konusma_suresi = "0 dk 0 sn"

    rows.append({
        "sohbet_id": sohbet["sohbet_id"],
        "tarih_saat": sohbet["tarih_saat"],
        "ilk_mesaj_tarihi": ilk_mesaj_tarihi,
        "son_mesaj_tarihi": son_mesaj_tarihi,
        "konusma_suresi_dakika": konusma_suresi,
        "tum_mesajlar": tum_mesajlar,
        "yanit_durumu": sohbet.get("yanit_durumu", ""),
        "sentiment": sohbet.get("sentiment", ""),
        "tur": sohbet.get("tur", ""),
        "intent": sohbet.get("intent", ""),
        "intent_detay": sohbet.get("intent_detay", "")
    })

# DataFrame oluştur
df = pd.DataFrame(rows)
df
# Out:
#     sohbet_id           tarih_saat    ilk_mesaj_tarihi    son_mesaj_tarihi  \
# 0       90001  04.09.2024 09:00:00 2024-09-04 09:00:00 2024-09-04 09:01:30
# 1       90002  04.09.2024 09:15:00 2024-09-04 09:15:00 2024-09-04 09:16:25
# 2       90003  04.09.2024 09:30:00 2024-09-04 09:30:00 2024-09-04 09:30:50
# 3       90004  04.09.2024 09:45:00 2024-09-04 09:45:00 2024-09-04 09:46:15
# 4       90005  04.09.2024 10:00:00 2024-09-04 10:00:00 2024-09-04 10:01:25
# 5       90006  04.09.2024 10:15:00 2024-09-04 10:15:00 2024-09-04 10:16:25
# 6       90007  04.09.2024 10:30:00 2024-09-04 10:30:00 2024-09-04 10:31:10
# 7       90008  04.09.2024 10:45:00 2024-09-04 10:45:00 2024-09-04 10:45:50
# 8       90009  04.09.2024 11:00:00 2024-09-04 11:00:00 2024-09-04 11:01:30
# 9       90010  04.09.2024 11:15:00 2024-09-04 11:15:00 2024-09-04 11:15:40
# 10      90011  04.09.2024 11:30:00 2024-09-04 11:30:00 2024-09-04 11:31:25
# 11      90012  04.09.2024 11:45:00 2024-09-04 11:45:00 2024-09-04 11:46:15
# 12      90013  04.09.2024 12:00:00 2024-09-04 12:00:00 2024-09-04 12:01:20
# 13      90014  04.09.2024 12:15:00 2024-09-04 12:15:00 2024-09-04 12:15:40
sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 28            1 dk 25 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 29            1 dk 20 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 30            1 dk 25 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 31            1 dk 10 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 32            1 dk 20 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 33            1 dk 15 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 34            1 dk 10 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 35            1 dk 25 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 36            1 dk 25 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 37            0 dk 55 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 38            1 dk 25 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
# 39            1 dk 10 sn  Bot: Merhaba! Ben AI Asistan. Size nasıl yardı...
#
#    yanit_durumu sentiment         tur            intent  \
# 0       Çözüldü   Pozitif     Şikayet        Eksik ürün
# 1    Çözülemedi   Negatif     Şikayet    Hesap Yönetimi
# 2       Çözüldü   Pozitif  Bilgi alma              İade
# 3    Çözülemedi   Negatif     Şikayet             Kupon
# 4       Çözüldü   Pozitif       İstek              İade
# 5       Çözüldü   Pozitif  Bilgi alma              İade
# 6    Çözülemedi   Negatif     Şikayet              İade
# 7       Çözüldü   Pozitif       İstek    Hesap Yönetimi
# 8       Çözüldü   Pozitif     Şikayet     Fatura sorunu
# 9    Çözülemedi   Negatif     Şikayet    Sipariş İptali
# 10      Çözüldü      Nötr  Bilgi alma              Stok
# 11   Çözülemedi   Negatif     Şikayet             Ödeme
# 12      Çözüldü   Pozitif  Bilgi alma             Kargo
# 13   Çözülemedi   Negatif     Şikayet             Ödeme
# 14      Çözüldü      Nötr  Bilgi alma        Beden/Uyum
# 15   Çözülemedi   Negatif     Şikayet      Adres Sorunu
# 16   Çözülemedi   Negatif     Şikayet             Yorum
# 17      Çözüldü   Pozitif     Şikayet      Teknik sorun
# 18   Çözülemedi   Negatif     Şikayet             Ödeme
# 19      Çözüldü   Pozitif  Bilgi alma              Ürün
# 20      Çözüldü   Pozitif     Şikayet        Eksik ürün
# 21   Çözülemedi   Negatif     Şikayet              İade
# 22      Çözüldü   Pozitif     Şikayet       Ürün Hatası
# 23   Çözülemedi   Negatif     Şikayet           Değişim
# 24      Çözüldü   Pozitif  Bilgi alma  Kampanya/İndirim
# 25      Çözüldü   Pozitif     Şikayet       Ürün Hatası
# 26      Çözüldü   Pozitif       İstek    Hesap Yönetimi
# 27   Çözülemedi   Negatif     Şikayet        Eksik ürün
# 28      Çözüldü   Pozitif     Şikayet              İade
# 29      Çözüldü   Pozitif  Bilgi alma      Adres Sorunu
# 30      Çözüldü   Pozitif  Bilgi alma           Sipariş
# 31   Çözülemedi   Negatif     Şikayet             Ödeme
# 32      Çözüldü   Pozitif       İstek        Beden/Uyum
# 33   Çözülemedi   Negatif     Şikayet             Kupon
# 34   Çözülemedi   Negatif     Şikayet             Kargo
# 35      Çözüldü   Pozitif       İstek    Sipariş İptali
# 36      Çözüldü   Pozitif     Şikayet       Ürün Hatası
# 37      Çözüldü   Pozitif       İstek          Abonelik
# 38      Çözüldü      Nötr     Şikayet             Kargo
# 39   Çözülemedi   Negatif     Şikayet              İade
#
#                                   intent_detay
# 0              Sipariş teslimatında eksik ürün
# 1                      E-posta linki gelmemesi
# 2                İade prosedürü hakkında bilgi
# 3                                 Kupon hatası
# 4                               Sipariş iptali
# 5                          İade kargosu takibi
# 6                         Değişim yapılamaması
# 7                     Hesap bilgisi güncelleme
# 8                         Fatura fiyatı hatası
# 9                  Sipariş iptali yapılamaması
# 10                        Stok yenileme tarihi
# 11                                 Çifte çekim
# 12                                Kargo takibi
# 13                    Kredi kartı reddedilmesi
# 14                          Ürün beden tablosu
# 15                         Yanlış adres girişi
# 16                        Yorum yayınlanmaması
# 17                                 Teknik hata
# 18  Hesaptan para çekilip siparişin oluşmaması
# 19                                Ürün bilgisi
# 20                    Eksik promosyon ürünleri
# 21                       Para iadesi gecikmesi
# 22                     Kargodan kaynaklı hasar
# 23                        Değişim yapılamaması
# 24                            Kampanya bilgisi
# 25                       Yanlış ürün gönderimi
# 26                               Hesap kapatma
# 27             Sipariş teslimatında eksik ürün
# 28                İade kodunun geçersiz olması
# 29                         Yanlış adres girişi
# 30                              Sipariş durumu
# 31                    Ödemenin tamamlanamaması
# 32                           Beden uyuşmazlığı
# 33                                Kupon hatası
# 34                                Kargo takibi
# 35                 Sipariş iptali yapılamaması
# 36                           Ürün tamir isteği
# 37                    E-posta aboneliği iptali
# 38                          Kargonun gecikmesi
# 39                       İade süreci gecikmesi

# %%
meta_sutunlar = ["sohbet_id", "ilk_mesaj_tarihi","son_mesaj_tarihi","konusma_suresi_dakika", "yanit_durumu", "sentiment", "tur", "intent", "intent_detay"]
df_meta = df[meta_sutunlar].copy()
df_meta
# Out:
#     sohbet_id    ilk_mesaj_tarihi    son_mesaj_tarihi konusma_suresi_dakika  \
# 0       90001 2024-09-04 09:00:00 2024-09-04 09:01:30            1 dk 30 sn
# 1       90002 2024-09-04 09:15:00 2024-09-04 09:16:25            1 dk 25 sn
# 2       90003 2024-09-04 09:30:00 2024-09-04 09:30:50            0 dk 50 sn
# 3       90004 2024-09-04 09:45:00 2024-09-04 09:46:15            1 dk 15 sn
# 4       90005 2024-09-04 10:00:00 2024-09-04 10:01:25            1 dk 25 sn
# 5       90006 2024-09-04 10:15:00 2024-09-04 10:16:25            1 dk 25 sn
# 6       90007 2024-09-04 10:30:00 2024-09-04 10:31:10            1 dk 10 sn
# 7       90008 2024-09-04 10:45:00 2024-09-04 10:45:50            0 dk 50 sn
# 8       90009 2024-09-04 11:00:00 2024-09-04 11:01:30            1 dk 30 sn
# 9       90010 2024-09-04 11:15:00 2024-09-04 11:15:40            0 dk 40 sn
# 10      90011 2024-09-04 11:30:00 2024-09-04 11:31:25            1 dk 25 sn
# 11      90012 2024-09-04 11:45:00 2024-09-04 11:46:15            1 dk 15 sn
# 12      90013 2024-09-04 12:00:00 2024-09-04 12:01:20            1 dk 20 sn
# 13      90014 2024-09-04 12:15:00 2024-09-04 12:15:40            0 dk 40 sn
# 14      90015 2024-09-04 12:30:00 2024-09-04 12:30:55            0 dk 55 sn
# 15      90016 2024-09-04 12:45:00 2024-09-04 12:46:15            1 dk 15 sn
# 16      90017 2024-09-04 13:00:00 2024-09-04 13:00:40            0 dk 40 sn
# 17      90018 2024-09-04 13:15:00 2024-09-04 13:15:55            0 dk 55 sn
# 19      Çözüldü   Pozitif  Bilgi alma              Ürün
# 20      Çözüldü   Pozitif     Şikayet        Eksik ürün
# 21   Çözülemedi   Negatif     Şikayet              İade
# 22      Çözüldü   Pozitif     Şikayet       Ürün Hatası
# 23   Çözülemedi   Negatif     Şikayet           Değişim
# 24      Çözüldü   Pozitif  Bilgi alma  Kampanya/İndirim
# 25      Çözüldü   Pozitif     Şikayet       Ürün Hatası
# 26      Çözüldü   Pozitif       İstek    Hesap Yönetimi
# 27   Çözülemedi   Negatif     Şikayet        Eksik ürün
# 28      Çözüldü   Pozitif     Şikayet              İade
# 29      Çözüldü   Pozitif  Bilgi alma      Adres Sorunu
# 30      Çözüldü   Pozitif  Bilgi alma           Sipariş
# 31   Çözülemedi   Negatif     Şikayet             Ödeme
# 32      Çözüldü   Pozitif       İstek        Beden/Uyum
# 33   Çözülemedi   Negatif     Şikayet             Kupon
# 34   Çözülemedi   Negatif     Şikayet             Kargo
# 35      Çözüldü   Pozitif       İstek    Sipariş İptali
# 36      Çözüldü   Pozitif     Şikayet       Ürün Hatası
# 37      Çözüldü   Pozitif       İstek          Abonelik
# 38      Çözüldü      Nötr     Şikayet             Kargo
# 39   Çözülemedi   Negatif     Şikayet              İade
#
#                                   intent_detay
# 0              Sipariş teslimatında eksik ürün
# 1                      E-posta linki gelmemesi
# 2                İade prosedürü hakkında bilgi
# 3                                 Kupon hatası
# 4                               Sipariş iptali
# 5                          İade kargosu takibi
# 6                         Değişim yapılamaması
# 7                     Hesap bilgisi güncelleme
# 8                         Fatura fiyatı hatası
# 9                  Sipariş iptali yapılamaması
# 10                        Stok yenileme tarihi
# 11                                 Çifte çekim
# 12                                Kargo takibi
# 13                    Kredi kartı reddedilmesi
# 14                          Ürün beden tablosu
# 15                         Yanlış adres girişi
# 16                        Yorum yayınlanmaması
# 17                                 Teknik hata
# 18  Hesaptan para çekilip siparişin oluşmaması
# 19                                Ürün bilgisi
# 20                    Eksik promosyon ürünleri
# 21                       Para iadesi gecikmesi
# 22                     Kargodan kaynaklı hasar
# 23                        Değişim yapılamaması
# 24                            Kampanya bilgisi
# 25                       Yanlış ürün gönderimi
# 26                               Hesap kapatma
# 27             Sipariş teslimatında eksik ürün
# 28                İade kodunun geçersiz olması
# 29                         Yanlış adres girişi
# 30                              Sipariş durumu
# 31                    Ödemenin tamamlanamaması
# 32                           Beden uyuşmazlığı
# 33                                Kupon hatası
# 34                                Kargo takibi
# 35                 Sipariş iptali yapılamaması
# 36                           Ürün tamir isteği
# 37                    E-posta aboneliği iptali
# 38                          Kargonun gecikmesi
# 39                       İade süreci gecikmesi

# %%
df_meta.to_csv("manuel_labels.csv",index=False,encoding="utf-8")

# %%
from openai import OpenAI
import os

# %%
from dotenv import load_dotenv


load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
# OpenAI client oluştur
client = OpenAI(api_key=api_key)


MODEL = "gpt-5-nano"

# %%
def promptOlusturYanitlandimi(mesaj):
    prompt=f"""
Aşağıdaki müşteri-bot sohbetini analiz et. Sohbetin tamamını dikkate al, tek mesaj bazlı davranma. 
Amacın, müşterinin sorunu veya talebinin bot tarafından nasıl yanıtlandığını belirlemek ve doğru 
"yanıt_durumu" etiketini vermektir.

Sohbet:
{mesaj}
Kurallar ve kriterler:
1. Yanıt durumu yalnızca **Çözüldü** veya **Çözülemedi** olmalıdır.
2. Çözüldü: Müşterinin sorunu tamamen çözülmüş, talebi karşılanmış veya gerekli bilgi verilmişse.
3. Çözülemedi: Müşterinin sorunu çözülmemiş, talep karşılanmamış veya sorun devam ediyorsa.
4. Hiçbir ek açıklama, yorum veya başka kelime kullanma.
5. Kararı verirken sohbetin tamamını göz önünde bulundur; yalnızca son mesaja bakma.

Yalnızca **Çözüldü** veya **Çözülemedi** olarak cevap ver:
"""

    return prompt

# %%
def prompt_olusturSentiment(mesaj):
    prompt= f"""
Türkçe konuşuyorum. Aşağıda kullanıcının (user) bir botla yaptığı görüşmenin tüm mesajları var. 
Bu mesajları bir konuşma analizi uzmanı gibi değerlendir. Analiz sonucunu yazmana gerek yok. 
Amacın, kullanıcının genel duygusal tonunu (sentiment) belirlemektir.

**Sentiment Etiketleme Mantığı**:
- **Pozitif**: Kullanıcının mesajları tamamen olumlu, kullanıcının mesajları memnuniyet veya teşekkür gibi ifadeler içeriyorsa.
- **Negatif**: Kullanıcının mesajları şikayet, hayal kırıklığı veya olumsuz duygu içeriyorsa.
- **Nötr**: Kullanıcının mesajları net bir şekilde pozitif veya negatif değilse; bilgi alma, soru veya karışık ifadeler içeriyorsa.
- Her mesajı ayrı ayrı değerlendir, ancak etiketi **konuşmanın geneline bakarak** belirle.

**Kurallar**:
1. Cevap yalnızca **Pozitif**, **Negatif** veya **Nötr** olmalı.
2. Hiçbir ek açıklama, yorum veya noktalama ekleme.
3. Kararı verirken tüm konuşmayı göz önünde bulundur, tek mesajla karar verme.
4. Cevap formatı: "Pozitif" veya "Negatif" veya "Nötr" tek kelime
5. talimatları asla ihlal etme

Bot-User görüşmesi:
"{mesaj}"
"""

    
    return prompt

# %%
def prompt_olusturTur(mesaj):
    prompt = f"""
Türkçe konuşuyorum. Sen bir **konuşma analizi uzmanısın**. Aşağıda bir kullanıcı ile bot arasındaki görüşme var.
Amacın, sohbetin genel türünü belirlemektir. Cevap **sadece bir etiket** olmalı.

**Sohbet Türleri, Açıklamaları ve Örnekleri**:

1. **Şikayet**: Kullanıcı bir ürün, hizmet veya deneyimden memnun değil sorun caarsa ve olumsuz geri bildirim veriyor.
   - Örnekler:
     - "Ürün elime geç geldi, çok geç kaldınız."
     - "Uygulama sürekli hata veriyor, kullanamıyorum."
     - "Müşteri hizmetleri çok yavaş ve yardımcı olmuyor."
     - "Siteye giriş yapamıyorum."
     - "Ödeme sırasında hata alıyorum."
     - "Uygulama yüklenmiyor veya donuyor."

2. **İstek**: Kullanıcı bir ürün, hizmet veya bilgi için talepte bulunuyor.
   - Örnekler:
     - "Ürünü iptal,iade etmek istiyorum."
     - "Ekstra bilgi gönderebilir misiniz?"
     - "Fatura kopyasını alabilir miyim?"

3. **Bilgi alma**: Kullanıcı süreç, prosedür veya kullanım ile ilgili detaylı bilgi istiyor.
   - Örnekler:
     - "İade süreci nasıl işliyor, adım adım anlatabilir misiniz?"
     - "Üyelik yenileme adımları nelerdir?"
     - "Ürünü nasıl kuracağımı detaylı şekilde açıklayabilir misiniz?"
     - "Siparişimi nasıl takip edebilirim?"
     - "Bu ürünün garanti süresi nedir?"
     - "Kampanya ne zaman bitiyor?"


**Kurallar**:
1. Cevap **sadece yukarıdaki etiketlerden biri** olmalı (Şikayet, İstek, Bilgi alma).
2. Hiçbir ek açıklama, yorum veya noktalama ekleme.
3. Kararı verirken sohbetin tamamını göz önünde bulundur.

**Sohbet:**
"{mesaj}"
"""
    return prompt

# %%
def prompt_olusturKonu(mesaj):
    intents = [
        "İade",
        "Sipariş İptali",
        "Ödeme",
        "Eksik ürün",
        "Kargo",
        "Kupon",
        "Adres Sorunu",
        "Ürün Hatası",
        "Hesap Yönetimi",
        "Stok",
        "Fatura sorunu",
        "Beden/Uyum",
        "Teknik sorun",
        "Kampanya/İndirim",
        "Abonelik",
        "Yorum",
        "Ürün",
        "Değişim",
        "Sipariş"
    ]

    prompt = f"""
Türkçe konuşuyorum. Sen bir konuşma-analizi uzmanısın. Aşağıda bir kullanıcı ile bot arasındaki görüşme var.
Amacın: kullanıcının sohbet içindeki **tek ve en uygun intent**ini belirlemek.

KURALLAR (mutlak):
1) Cevap **sadece** aşağıdaki intentlerden biri olmalı **tam olarak** şu şekilde (büyük/küçük harf duyarlı):
{', '.join(intents)}
2) Hiçbir ek açıklama, yorum, noktalama işareti, tırnak işareti veya boşluk ekleme. Sadece verilen intentlerden birini yaz.
3) Kararı verirken **sohbetin tamamını** değerlendir; tek bir mesaj değil tüm konuşma zinciri esas alınır.
4) Ürün hatası ve İade etiketlerini dikkatli degerlendir


Bot-User görüşmesi:
\"{mesaj}\"
"""
    return prompt

# %%
def prompt_olusturKonuDetay(mesaj):
    detay_listesi = [
        "Para iadesi gecikmesi",
        "İade kargosu takibi",
        "Çifte çekim",
        "Kredi kartı reddedilmesi",
        "Ödemenin tamamlanamaması",
        "Fatura fiyatı hatası",
        "Sipariş teslimatında eksik ürün",
        "Eksik promosyon ürünleri",
        "Kargodan kaynaklı hasar",
        "Yanlış ürün gönderimi",
        "Yanlış adres girişi",
        "Değişim yapılamaması",
        "Stok yenileme tarihi",
        "Ürün beden tablosu",
        "Ürün bilgisi",
        "Beden uyuşmazlığı",
        "Hesap kapatma",
        "Teknik hata",
        "E-posta linki gelmemesi",
        "Yorum yayınlanmaması",
        "Kampanya bilgisi",
        "E-posta aboneliği iptali",
        "Sipariş iptali yapılamaması",
        "Hesap bilgisi güncelleme",
        "Kargo takibi",
        "Hesaptan para çekilip siparişin oluşmaması",
        "İade kodunun geçersiz olması",
        "Kupon hatası",
        "Ürün tamir isteği",
        "İade süreci gecikmesi",
        "Sipariş iptali",
        "Sipariş durumu"
    ]

    prompt = f"""
Türkçe konuşuyorum. Sen bir **konuşma analizi uzmanısın**. 
Aşağıda bir kullanıcı ile bot arasındaki görüşme var. 
Amacın, kullanıcının **sohbet içindeki spesifik sorununun veya isteğinin detayını (intent_detay)** tespit etmektir.

**Intent Detay Mantığı**:
- Intent = Kullanıcının genel amacı (ör. İade, Ödeme, Kargo).
- Intent Detay = Bu amacın daha spesifik açıklaması (ör. Para iadesi gecikmesi, Çifte çekim, Yanlış adres girişi).

**Kurallar**:
1. Cevap **sadece** aşağıdaki intent_detay listesinden biri olmalı.  
2. Yanıt **tam olarak** listedeki biçimde olmalı (büyük/küçük harf ve yazım aynen korunmalı).  
3. Hiçbir ek açıklama, yorum veya noktalama ekleme.  
4. Sohbetin tamamını değerlendir, tek mesaja göre karar verme.  

**Geçerli intent_detay listesi**:
{", ".join(detay_listesi)}

**Bot-User görüşmesi**:
\"{mesaj}\"
"""
    return prompt

# %%
def llm_etiketle(mesaj):
    try:
        response = client.chat.completions.create(
            model=MODEL,
            messages=[ {"role": "system", "content": "Sen bir konusma analizi uzmanısın. Talimatları asla ihlal etme. Sadece istenen formatta yanıt ver."},
                {"role": "user", "content": mesaj}
            ],
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Hata: {e}")
        return "HATA"

# %%
df_yeni=pd.DataFrame(columns=["sohbet_id","ilk_mesaj_tarihi","son_mesaj_tarihi","konusma_suresi_dakika","yanit_durumu","sentiment","tur","intent","intent_detay"])
df_yeni
# Out:
# Empty DataFrame
# Columns: [sohbet_id, ilk_mesaj_tarihi, son_mesaj_tarihi, konusma_suresi_dakika, yanit_durumu, sentiment, tur, intent, intent_detay]
# Index: []

# %%
df_yeni["sohbet_id"]=df["sohbet_id"]
df_yeni["ilk_mesaj_tarihi"]=df["ilk_mesaj_tarihi"]
df_yeni["son_mesaj_tarihi"]=df["son_mesaj_tarihi"]
df_yeni["konusma_suresi_dakika"]=df["konusma_suresi_dakika"]
df_yeni
# Out:
#     sohbet_id    ilk_mesaj_tarihi    son_mesaj_tarihi konusma_suresi_dakika  \
# 20      90021 2024-09-04 14:00:00 2024-09-04 14:01:30            1 dk 30 sn
# 21      90022 2024-09-04 14:15:00 2024-09-04 14:16:10            1 dk 10 sn
# 22      90023 2024-09-04 14:30:00 2024-09-04 14:31:20            1 dk 20 sn
# 23      90024 2024-09-04 14:45:00 2024-09-04 14:45:40            0 dk 40 sn
# 24      90025 2024-09-04 15:00:00 2024-09-04 15:00:55            0 dk 55 sn
# 25      90026 2024-09-04 15:15:00 2024-09-04 15:16:20            1 dk 20 sn
# 26      90027 2024-09-04 15:30:00 2024-09-04 15:30:55            0 dk 55 sn
# 27      90028 2024-09-04 15:45:00 2024-09-04 15:46:15            1 dk 15 sn
# 28      90029 2024-09-04 16:00:00 2024-09-04 16:01:25            1 dk 25 sn
# 29      90030 2024-09-04 16:15:00 2024-09-04 16:16:20            1 dk 20 sn
# 30      90031 2024-09-04 16:30:00 2024-09-04 16:31:25            1 dk 25 sn
# 31      90032 2024-09-04 16:45:00 2024-09-04 16:46:10            1 dk 10 sn
# 32      90033 2024-09-04 17:00:00 2024-09-04 17:01:20            1 dk 20 sn
# 33      90034 2024-09-04 17:15:00 2024-09-04 17:16:15            1 dk 15 sn
# 34      90035 2024-09-04 17:30:00 2024-09-04 17:31:10            1 dk 10 sn
# 35      90036 2024-09-04 17:45:00 2024-09-04 17:46:25            1 dk 25 sn
# 36      90037 2024-09-04 18:00:00 2024-09-04 18:01:25            1 dk 25 sn
# 37      90038 2024-09-04 18:15:00 2024-09-04 18:15:55            0 dk 55 sn
# 38      90039 2024-09-04 18:30:00 2024-09-04 18:31:25            1 dk 25 sn
# 39      90040 2024-09-04 18:45:00 2024-09-04 18:46:10            1 dk 10 sn
#
#    yanit_durumu sentiment  tur intent intent_detay
# 20          NaN       NaN  NaN    NaN          NaN
# 21          NaN       NaN  NaN    NaN          NaN
# 22          NaN       NaN  NaN    NaN          NaN
# 23          NaN       NaN  NaN    NaN          NaN
# 24          NaN       NaN  NaN    NaN          NaN
# 25          NaN       NaN  NaN    NaN          NaN
# 26          NaN       NaN  NaN    NaN          NaN
# 27          NaN       NaN  NaN    NaN          NaN
# 28          NaN       NaN  NaN    NaN          NaN
# 29          NaN       NaN  NaN    NaN          NaN
# 30          NaN       NaN  NaN    NaN          NaN
# 31          NaN       NaN  NaN    NaN          NaN
# 32          NaN       NaN  NaN    NaN          NaN
# 33          NaN       NaN  NaN    NaN          NaN
# 34          NaN       NaN  NaN    NaN          NaN
# 35          NaN       NaN  NaN    NaN          NaN
# 36          NaN       NaN  NaN    NaN          NaN
# 37          NaN       NaN  NaN    NaN          NaN
# 38          NaN       NaN  NaN    NaN          NaN
# 39          NaN       NaN  NaN    NaN          NaN

# %%
df_yeni["yanit_durumu"] = df["tum_mesajlar"].apply(lambda x: llm_etiketle(promptOlusturYanitlandimi(x)))

# %%
df_yeni
# Out:
#     sohbet_id    ilk_mesaj_tarihi    son_mesaj_tarihi konusma_suresi_dakika  \
# 20      90021 2024-09-04 14:00:00 2024-09-04 14:01:30            1 dk 30 sn
# 21      90022 2024-09-04 14:15:00 2024-09-04 14:16:10            1 dk 10 sn
# 22      90023 2024-09-04 14:30:00 2024-09-04 14:31:20            1 dk 20 sn
# 23      90024 2024-09-04 14:45:00 2024-09-04 14:45:40            0 dk 40 sn
# 24      90025 2024-09-04 15:00:00 2024-09-04 15:00:55            0 dk 55 sn
# 25      90026 2024-09-04 15:15:00 2024-09-04 15:16:20            1 dk 20 sn
# 26      90027 2024-09-04 15:30:00 2024-09-04 15:30:55            0 dk 55 sn
# 27      90028 2024-09-04 15:45:00 2024-09-04 15:46:15            1 dk 15 sn
# 28      90029 2024-09-04 16:00:00 2024-09-04 16:01:25            1 dk 25 sn
# 29      90030 2024-09-04 16:15:00 2024-09-04 16:16:20            1 dk 20 sn
# 30      90031 2024-09-04 16:30:00 2024-09-04 16:31:25            1 dk 25 sn
# 31      90032 2024-09-04 16:45:00 2024-09-04 16:46:10            1 dk 10 sn
# 32      90033 2024-09-04 17:00:00 2024-09-04 17:01:20            1 dk 20 sn
# 33      90034 2024-09-04 17:15:00 2024-09-04 17:16:15            1 dk 15 sn
# 34      90035 2024-09-04 17:30:00 2024-09-04 17:31:10            1 dk 10 sn
# 35      90036 2024-09-04 17:45:00 2024-09-04 17:46:25            1 dk 25 sn
# 36      90037 2024-09-04 18:00:00 2024-09-04 18:01:25            1 dk 25 sn
# 37      90038 2024-09-04 18:15:00 2024-09-04 18:15:55            0 dk 55 sn
# 38      90039 2024-09-04 18:30:00 2024-09-04 18:31:25            1 dk 25 sn
# 39      90040 2024-09-04 18:45:00 2024-09-04 18:46:10            1 dk 10 sn
#
#    yanit_durumu sentiment  tur intent intent_detay
# 20      Çözüldü       NaN  NaN    NaN          NaN
# 21   Çözülemedi       NaN  NaN    NaN          NaN
# 22      Çözüldü       NaN  NaN    NaN          NaN
# 23   Çözülemedi       NaN  NaN    NaN          NaN
# 24      Çözüldü       NaN  NaN    NaN          NaN
# 25      Çözüldü       NaN  NaN    NaN          NaN
# 26      Çözüldü       NaN  NaN    NaN          NaN
# 27   Çözülemedi       NaN  NaN    NaN          NaN
# 28      Çözüldü       NaN  NaN    NaN          NaN
# 29      Çözüldü       NaN  NaN    NaN          NaN
# 30      Çözüldü       NaN  NaN    NaN          NaN
# 31   Çözülemedi       NaN  NaN    NaN          NaN
# 32      Çözüldü       NaN  NaN    NaN          NaN
# 33   Çözülemedi       NaN  NaN    NaN          NaN
# 34   Çözülemedi       NaN  NaN    NaN          NaN
# 35      Çözüldü       NaN  NaN    NaN          NaN
# 36   Çözülemedi       NaN  NaN    NaN          NaN
# 37      Çözüldü       NaN  NaN    NaN          NaN
# 38      Çözüldü       NaN  NaN    NaN          NaN
# 39   Çözülemedi       NaN  NaN    NaN          NaN

# %%
df_yeni["sentiment"]=df["tum_mesajlar"].apply(lambda x: llm_etiketle(prompt_olusturSentiment(x)))
df_yeni
# Out:
#     sohbet_id    ilk_mesaj_tarihi    son_mesaj_tarihi konusma_suresi_dakika  \
# 20      90021 2024-09-04 14:00:00 2024-09-04 14:01:30            1 dk 30 sn
# 21      90022 2024-09-04 14:15:00 2024-09-04 14:16:10            1 dk 10 sn
# 22      90023 2024-09-04 14:30:00 2024-09-04 14:31:20            1 dk 20 sn
# 23      90024 2024-09-04 14:45:00 2024-09-04 14:45:40            0 dk 40 sn
# 24      90025 2024-09-04 15:00:00 2024-09-04 15:00:55            0 dk 55 sn
# 25      90026 2024-09-04 15:15:00 2024-09-04 15:16:20            1 dk 20 sn
# 26      90027 2024-09-04 15:30:00 2024-09-04 15:30:55            0 dk 55 sn
# 27      90028 2024-09-04 15:45:00 2024-09-04 15:46:15            1 dk 15 sn
# 28      90029 2024-09-04 16:00:00 2024-09-04 16:01:25            1 dk 25 sn
# 29      90030 2024-09-04 16:15:00 2024-09-04 16:16:20            1 dk 20 sn
# 30      90031 2024-09-04 16:30:00 2024-09-04 16:31:25            1 dk 25 sn
# 31      90032 2024-09-04 16:45:00 2024-09-04 16:46:10            1 dk 10 sn
# 32      90033 2024-09-04 17:00:00 2024-09-04 17:01:20            1 dk 20 sn
# 33      90034 2024-09-04 17:15:00 2024-09-04 17:16:15            1 dk 15 sn
# 34      90035 2024-09-04 17:30:00 2024-09-04 17:31:10            1 dk 10 sn
# 35      90036 2024-09-04 17:45:00 2024-09-04 17:46:25            1 dk 25 sn
# 36      90037 2024-09-04 18:00:00 2024-09-04 18:01:25            1 dk 25 sn
# 37      90038 2024-09-04 18:15:00 2024-09-04 18:15:55            0 dk 55 sn
# 38      90039 2024-09-04 18:30:00 2024-09-04 18:31:25            1 dk 25 sn
# 39      90040 2024-09-04 18:45:00 2024-09-04 18:46:10            1 dk 10 sn
#
#    yanit_durumu sentiment  tur intent intent_detay
# 20      Çözüldü   Pozitif  NaN    NaN          NaN
# 21   Çözülemedi   Negatif  NaN    NaN          NaN
# 22      Çözüldü   Pozitif  NaN    NaN          NaN
# 23   Çözülemedi   Negatif  NaN    NaN          NaN
# 24      Çözüldü   Pozitif  NaN    NaN          NaN
# 25      Çözüldü   Pozitif  NaN    NaN          NaN
# 26      Çözüldü   Pozitif  NaN    NaN          NaN
# 27   Çözülemedi   Negatif  NaN    NaN          NaN
# 28      Çözüldü   Pozitif  NaN    NaN          NaN
# 29      Çözüldü   Pozitif  NaN    NaN          NaN
# 30      Çözüldü   Pozitif  NaN    NaN          NaN
# 31   Çözülemedi   Negatif  NaN    NaN          NaN
# 32      Çözüldü   Pozitif  NaN    NaN          NaN
# 33   Çözülemedi   Negatif  NaN    NaN          NaN
# 34   Çözülemedi   Negatif  NaN    NaN          NaN
# 35      Çözüldü   Pozitif  NaN    NaN          NaN
# 36   Çözülemedi      Nötr  NaN    NaN          NaN
# 37      Çözüldü   Pozitif  NaN    NaN          NaN
# 38      Çözüldü      Nötr  NaN    NaN          NaN
# 39   Çözülemedi   Negatif  NaN    NaN          NaN

# %%
df_yeni["tur"]=df["tum_mesajlar"].apply(lambda x: llm_etiketle(prompt_olusturTur(x)))
df_yeni
# Out:
#     sohbet_id    ilk_mesaj_tarihi    son_mesaj_tarihi konusma_suresi_dakika  \
# 20      90021 2024-09-04 14:00:00 2024-09-04 14:01:30            1 dk 30 sn
# 21      90022 2024-09-04 14:15:00 2024-09-04 14:16:10            1 dk 10 sn
# 22      90023 2024-09-04 14:30:00 2024-09-04 14:31:20            1 dk 20 sn
# 23      90024 2024-09-04 14:45:00 2024-09-04 14:45:40            0 dk 40 sn
# 24      90025 2024-09-04 15:00:00 2024-09-04 15:00:55            0 dk 55 sn
# 25      90026 2024-09-04 15:15:00 2024-09-04 15:16:20            1 dk 20 sn
# 26      90027 2024-09-04 15:30:00 2024-09-04 15:30:55            0 dk 55 sn
# 27      90028 2024-09-04 15:45:00 2024-09-04 15:46:15            1 dk 15 sn
# 28      90029 2024-09-04 16:00:00 2024-09-04 16:01:25            1 dk 25 sn
# 29      90030 2024-09-04 16:15:00 2024-09-04 16:16:20            1 dk 20 sn
# 30      90031 2024-09-04 16:30:00 2024-09-04 16:31:25            1 dk 25 sn
# 31      90032 2024-09-04 16:45:00 2024-09-04 16:46:10            1 dk 10 sn
# 32      90033 2024-09-04 17:00:00 2024-09-04 17:01:20            1 dk 20 sn
# 33      90034 2024-09-04 17:15:00 2024-09-04 17:16:15            1 dk 15 sn
# 34      90035 2024-09-04 17:30:00 2024-09-04 17:31:10            1 dk 10 sn
# 35      90036 2024-09-04 17:45:00 2024-09-04 17:46:25            1 dk 25 sn
# 36      90037 2024-09-04 18:00:00 2024-09-04 18:01:25            1 dk 25 sn
# 37      90038 2024-09-04 18:15:00 2024-09-04 18:15:55            0 dk 55 sn
# 38      90039 2024-09-04 18:30:00 2024-09-04 18:31:25            1 dk 25 sn
# 39      90040 2024-09-04 18:45:00 2024-09-04 18:46:10            1 dk 10 sn
#
#    yanit_durumu sentiment         tur intent intent_detay
# 20      Çözüldü   Pozitif     Şikayet    NaN          NaN
# 21   Çözülemedi   Negatif     Şikayet    NaN          NaN
# 22      Çözüldü   Pozitif     Şikayet    NaN          NaN
# 23   Çözülemedi   Negatif     Şikayet    NaN          NaN
# 24      Çözüldü   Pozitif  Bilgi alma    NaN          NaN
# 25      Çözüldü   Pozitif     Şikayet    NaN          NaN
# 26      Çözüldü   Pozitif       İstek    NaN          NaN
# 27   Çözülemedi   Negatif     Şikayet    NaN          NaN
# 28      Çözüldü   Pozitif     Şikayet    NaN          NaN
# 29      Çözüldü   Pozitif  Bilgi alma    NaN          NaN
# 30      Çözüldü   Pozitif  Bilgi alma    NaN          NaN
# 31   Çözülemedi   Negatif     Şikayet    NaN          NaN
# 32      Çözüldü   Pozitif     Şikayet    NaN          NaN
# 33   Çözülemedi   Negatif     Şikayet    NaN          NaN
# 34   Çözülemedi   Negatif     Şikayet    NaN          NaN
# 35      Çözüldü   Pozitif       İstek    NaN          NaN
# 36   Çözülemedi      Nötr       İstek    NaN          NaN
# 37      Çözüldü   Pozitif       İstek    NaN          NaN
# 38      Çözüldü      Nötr     Şikayet    NaN          NaN
# 39   Çözülemedi   Negatif     Şikayet    NaN          NaN

# %%
df_yeni["intent"]=df["tum_mesajlar"].apply(lambda x: llm_etiketle(prompt_olusturKonu(x)))

# %%
df_yeni
# Out:
#     sohbet_id    ilk_mesaj_tarihi    son_mesaj_tarihi konusma_suresi_dakika  \
# 20      90021 2024-09-04 14:00:00 2024-09-04 14:01:30            1 dk 30 sn
# 21      90022 2024-09-04 14:15:00 2024-09-04 14:16:10            1 dk 10 sn
# 22      90023 2024-09-04 14:30:00 2024-09-04 14:31:20            1 dk 20 sn
# 23      90024 2024-09-04 14:45:00 2024-09-04 14:45:40            0 dk 40 sn
# 24      90025 2024-09-04 15:00:00 2024-09-04 15:00:55            0 dk 55 sn
# 25      90026 2024-09-04 15:15:00 2024-09-04 15:16:20            1 dk 20 sn
# 26      90027 2024-09-04 15:30:00 2024-09-04 15:30:55            0 dk 55 sn
# 27      90028 2024-09-04 15:45:00 2024-09-04 15:46:15            1 dk 15 sn
# 28      90029 2024-09-04 16:00:00 2024-09-04 16:01:25            1 dk 25 sn
# 29      90030 2024-09-04 16:15:00 2024-09-04 16:16:20            1 dk 20 sn
# 30      90031 2024-09-04 16:30:00 2024-09-04 16:31:25            1 dk 25 sn
# 31      90032 2024-09-04 16:45:00 2024-09-04 16:46:10            1 dk 10 sn
# 32      90033 2024-09-04 17:00:00 2024-09-04 17:01:20            1 dk 20 sn
# 33      90034 2024-09-04 17:15:00 2024-09-04 17:16:15            1 dk 15 sn
# 34      90035 2024-09-04 17:30:00 2024-09-04 17:31:10            1 dk 10 sn
# 35      90036 2024-09-04 17:45:00 2024-09-04 17:46:25            1 dk 25 sn
# 36      90037 2024-09-04 18:00:00 2024-09-04 18:01:25            1 dk 25 sn
# 37      90038 2024-09-04 18:15:00 2024-09-04 18:15:55            0 dk 55 sn
# 38      90039 2024-09-04 18:30:00 2024-09-04 18:31:25            1 dk 25 sn
# 39      90040 2024-09-04 18:45:00 2024-09-04 18:46:10            1 dk 10 sn
#
#    yanit_durumu sentiment         tur            intent intent_detay
# 20      Çözüldü   Pozitif     Şikayet        Eksik ürün          NaN
# 21   Çözülemedi   Negatif     Şikayet              İade          NaN
# 22      Çözüldü   Pozitif     Şikayet           Değişim          NaN
# 23   Çözülemedi   Negatif     Şikayet           Değişim          NaN
# 24      Çözüldü   Pozitif  Bilgi alma  Kampanya/İndirim          NaN
# 25      Çözüldü   Pozitif     Şikayet           Değişim          NaN
# 26      Çözüldü   Pozitif       İstek    Hesap Yönetimi          NaN
# 27   Çözülemedi   Negatif     Şikayet        Eksik ürün          NaN
# 28      Çözüldü   Pozitif     Şikayet              İade          NaN
# 29      Çözüldü   Pozitif  Bilgi alma      Adres Sorunu          NaN
# 30      Çözüldü   Pozitif  Bilgi alma           Sipariş          NaN
# 31   Çözülemedi   Negatif     Şikayet             Ödeme          NaN
# 32      Çözüldü   Pozitif     Şikayet              İade          NaN
# 33   Çözülemedi   Negatif     Şikayet             Kupon          NaN
# 34   Çözülemedi   Negatif     Şikayet             Kargo          NaN
# 35      Çözüldü   Pozitif       İstek           Sipariş          NaN
# 36   Çözülemedi      Nötr       İstek       Ürün Hatası          NaN
# 37      Çözüldü   Pozitif       İstek          Abonelik          NaN
# 38      Çözüldü      Nötr     Şikayet             Kargo          NaN
# 39   Çözülemedi   Negatif     Şikayet              İade          NaN

# %%
df_yeni["intent_detay"]=df["tum_mesajlar"].apply(lambda x: llm_etiketle(prompt_olusturKonuDetay(x)))
df_yeni
# Out:
#     sohbet_id    ilk_mesaj_tarihi    son_mesaj_tarihi konusma_suresi_dakika  \
# 20      90021 2024-09-04 14:00:00 2024-09-04 14:01:30            1 dk 30 sn
# 21      90022 2024-09-04 14:15:00 2024-09-04 14:16:10            1 dk 10 sn
# 22      90023 2024-09-04 14:30:00 2024-09-04 14:31:20            1 dk 20 sn
# 23      90024 2024-09-04 14:45:00 2024-09-04 14:45:40            0 dk 40 sn
# 24      90025 2024-09-04 15:00:00 2024-09-04 15:00:55            0 dk 55 sn
# 25      90026 2024-09-04 15:15:00 2024-09-04 15:16:20            1 dk 20 sn
# 26      90027 2024-09-04 15:30:00 2024-09-04 15:30:55            0 dk 55 sn
# 27      90028 2024-09-04 15:45:00 2024-09-04 15:46:15            1 dk 15 sn
# 28      90029 2024-09-04 16:00:00 2024-09-04 16:01:25            1 dk 25 sn
# 29      90030 2024-09-04 16:15:00 2024-09-04 16:16:20            1 dk 20 sn
# 30      90031 2024-09-04 16:30:00 2024-09-04 16:31:25            1 dk 25 sn
# 31      90032 2024-09-04 16:45:00 2024-09-04 16:46:10            1 dk 10 sn
# 32      90033 2024-09-04 17:00:00 2024-09-04 17:01:20            1 dk 20 sn
# 33      90034 2024-09-04 17:15:00 2024-09-04 17:16:15            1 dk 15 sn
# 34      90035 2024-09-04 17:30:00 2024-09-04 17:31:10            1 dk 10 sn
# 35      90036 2024-09-04 17:45:00 2024-09-04 17:46:25            1 dk 25 sn
# 36      90037 2024-09-04 18:00:00 2024-09-04 18:01:25            1 dk 25 sn
# 37      90038 2024-09-04 18:15:00 2024-09-04 18:15:55            0 dk 55 sn
# 38      90039 2024-09-04 18:30:00 2024-09-04 18:31:25            1 dk 25 sn
# 39      90040 2024-09-04 18:45:00 2024-09-04 18:46:10            1 dk 10 sn
#
#    yanit_durumu sentiment         tur            intent  \
# 20      Çözüldü   Pozitif     Şikayet        Eksik ürün
# 21   Çözülemedi   Negatif     Şikayet              İade
# 22      Çözüldü   Pozitif     Şikayet           Değişim
# 23   Çözülemedi   Negatif     Şikayet           Değişim
# 24      Çözüldü   Pozitif  Bilgi alma  Kampanya/İndirim
# 25      Çözüldü   Pozitif     Şikayet           Değişim
# 26      Çözüldü   Pozitif       İstek    Hesap Yönetimi
# 27   Çözülemedi   Negatif     Şikayet        Eksik ürün
# 28      Çözüldü   Pozitif     Şikayet              İade
# 29      Çözüldü   Pozitif  Bilgi alma      Adres Sorunu
# 30      Çözüldü   Pozitif  Bilgi alma           Sipariş
# 31   Çözülemedi   Negatif     Şikayet             Ödeme
# 32      Çözüldü   Pozitif     Şikayet              İade
# 33   Çözülemedi   Negatif     Şikayet             Kupon
# 34   Çözülemedi   Negatif     Şikayet             Kargo
# 35      Çözüldü   Pozitif       İstek           Sipariş
# 36   Çözülemedi      Nötr       İstek       Ürün Hatası
# 37      Çözüldü   Pozitif       İstek          Abonelik
# 38      Çözüldü      Nötr     Şikayet             Kargo
# 39   Çözülemedi   Negatif     Şikayet              İade
#
#                        intent_detay
# 20         Eksik promosyon ürünleri
# 21            İade süreci gecikmesi
# 22          Kargodan kaynaklı hasar
# 23             Değişim yapılamaması
# 24                 Kampanya bilgisi
# 25            Yanlış ürün gönderimi
# 26                    Hesap kapatma
# 27  Sipariş teslimatında eksik ürün
# 26      Çözüldü   Pozitif       İstek    Hesap Yönetimi
# 27   Çözülemedi   Negatif     Şikayet        Eksik ürün
# 28      Çözüldü   Pozitif     Şikayet              İade
# 29      Çözüldü   Pozitif  Bilgi alma      Adres Sorunu
# 30      Çözüldü   Pozitif  Bilgi alma           Sipariş
# 31   Çözülemedi   Negatif     Şikayet             Ödeme
# 32      Çözüldü   Pozitif       İstek        Beden/Uyum
# 33   Çözülemedi   Negatif     Şikayet             Kupon
# 34   Çözülemedi   Negatif     Şikayet             Kargo
# 35      Çözüldü   Pozitif       İstek    Sipariş İptali
# 36      Çözüldü   Pozitif     Şikayet       Ürün Hatası
# 37      Çözüldü   Pozitif       İstek          Abonelik
# 38      Çözüldü      Nötr     Şikayet             Kargo
# 39   Çözülemedi   Negatif     Şikayet              İade
#
#                                   intent_detay
# 0              Sipariş teslimatında eksik ürün
# 1                      E-posta linki gelmemesi
# 2                İade prosedürü hakkında bilgi
# 3                                 Kupon hatası
# 4                               Sipariş iptali
# 5                          İade kargosu takibi
# 6                         Değişim yapılamaması
# 7                     Hesap bilgisi güncelleme
# 8                         Fatura fiyatı hatası
# 9                  Sipariş iptali yapılamaması
# 10                        Stok yenileme tarihi
# 11                                 Çifte çekim
# 12                                Kargo takibi
# 13                    Kredi kartı reddedilmesi
# 14                          Ürün beden tablosu
# 15                         Yanlış adres girişi
# 16                        Yorum yayınlanmaması
# 17                                 Teknik hata
# 18  Hesaptan para çekilip siparişin oluşmaması
# 19                                Ürün bilgisi
# 20                    Eksik promosyon ürünleri
# 21                       Para iadesi gecikmesi
# 22                     Kargodan kaynaklı hasar
# 23                        Değişim yapılamaması
# 24                            Kampanya bilgisi
# 25                       Yanlış ürün gönderimi
# 26                               Hesap kapatma
# 27             Sipariş teslimatında eksik ürün
# 28                İade kodunun geçersiz olması
# 29                         Yanlış adres girişi
# 30                              Sipariş durumu
# 31                    Ödemenin tamamlanamaması
# 32                           Beden uyuşmazlığı
# 33                                Kupon hatası
# 34                                Kargo takibi
# 35                 Sipariş iptali yapılamaması
# 36                           Ürün tamir isteği
# 37                    E-posta aboneliği iptali
# 38                          Kargonun gecikmesi
# 39                       İade süreci gecikmesi

# %%
df_yeni = pd.read_csv("gpt-5-nano-out1.csv")
df_yeni
# Out:
#     sohbet_id     ilk_mesaj_tarihi     son_mesaj_tarihi konusma_suresi_dakika  \
# 0       90001  2024-09-04 09:00:00  2024-09-04 09:01:30            1 dk 30 sn
# 1       90002  2024-09-04 09:15:00  2024-09-04 09:16:25            1 dk 25 sn
# 2       90003  2024-09-04 09:30:00  2024-09-04 09:30:50            0 dk 50 sn
# 3       90004  2024-09-04 09:45:00  2024-09-04 09:46:15            1 dk 15 sn
# 4       90005  2024-09-04 10:00:00  2024-09-04 10:01:25            1 dk 25 sn
# 5       90006  2024-09-04 10:15:00  2024-09-04 10:16:25            1 dk 25 sn
# 6       90007  2024-09-04 10:30:00  2024-09-04 10:31:10            1 dk 10 sn
# 3    Çözülemedi   Negatif     Şikayet             Kupon
# 4       Çözüldü   Pozitif       İstek    Sipariş İptali
# 5       Çözüldü   Pozitif  Bilgi alma              İade
# 6    Çözülemedi   Negatif     Şikayet              İade
# 7    Çözülemedi   Pozitif       İstek    Hesap Yönetimi
# 8    Çözülemedi      Nötr     Şikayet     Fatura sorunu
# 9    Çözülemedi   Negatif     Şikayet    Sipariş İptali
# 10      Çözüldü      Nötr  Bilgi alma              Stok
# 11   Çözülemedi   Negatif     Şikayet             Ödeme
# 12      Çözüldü   Pozitif  Bilgi alma             Kargo
# 13   Çözülemedi   Negatif     Şikayet             Ödeme
# 14      Çözüldü      Nötr  Bilgi alma        Beden/Uyum
# 15   Çözülemedi   Negatif     Şikayet      Adres Sorunu
# 16   Çözülemedi   Negatif     Şikayet             Yorum
# 17   Çözülemedi      Nötr     Şikayet      Teknik sorun
# 18   Çözülemedi   Negatif     Şikayet              İade
# 19      Çözüldü   Pozitif  Bilgi alma              Ürün
# 20      Çözüldü   Pozitif     Şikayet        Eksik ürün
# 21   Çözülemedi   Negatif     Şikayet              İade
# 22      Çözüldü   Pozitif     Şikayet           Değişim
# 23   Çözülemedi   Negatif     Şikayet           Değişim
# 24      Çözüldü   Pozitif  Bilgi alma  Kampanya/İndirim
# 25      Çözüldü   Pozitif     Şikayet           Değişim
# 26      Çözüldü   Pozitif       İstek    Hesap Yönetimi
# 27   Çözülemedi   Negatif     Şikayet        Eksik ürün
# 28      Çözüldü   Pozitif     Şikayet              İade
# 29      Çözüldü   Pozitif  Bilgi alma      Adres Sorunu
# 30      Çözüldü   Pozitif  Bilgi alma           Sipariş
# 31   Çözülemedi   Negatif     Şikayet             Ödeme
# 32      Çözüldü   Pozitif     Şikayet              İade
# 33   Çözülemedi   Negatif     Şikayet             Kupon
# 34   Çözülemedi   Negatif     Şikayet             Kargo
# 35      Çözüldü   Pozitif       İstek    Sipariş İptali
# 36   Çözülemedi      Nötr       İstek       Ürün Hatası
# 37      Çözüldü   Pozitif       İstek          Abonelik
# 38      Çözüldü      Nötr     Şikayet             Kargo
# 39   Çözülemedi   Negatif     Şikayet              İade
#
#                                   intent_detay
# 0              Sipariş teslimatında eksik ürün
# 1                      E-posta linki gelmemesi
# 2                        İade süreci gecikmesi
# 3                                 Kupon hatası
# 4                               Sipariş iptali
# 5                          İade kargosu takibi
# 6                        İade süreci gecikmesi
# 7                     Hesap bilgisi güncelleme
# 8                         Fatura fiyatı hatası
# 9                  Sipariş iptali yapılamaması
# 10                        Stok yenileme tarihi
# 11                                 Çifte çekim
# 12                                Kargo takibi
# 13                    Kredi kartı reddedilmesi
# 14                          Ürün beden tablosu
# 15                         Yanlış adres girişi
# 16                        Yorum yayınlanmaması
# 17                                 Teknik hata
# 18  Hesaptan para çekilip siparişin oluşmaması
# 19                                Ürün bilgisi
# 20                    Eksik promosyon ürünleri
# 21                       Para iadesi gecikmesi
# 22                     Kargodan kaynaklı hasar
# 23                        Değişim yapılamaması
# 24                            Kampanya bilgisi
# 25                       Yanlış ürün gönderimi
# 26                               Hesap kapatma
# 27             Sipariş teslimatında eksik ürün
# 28                İade kodunun geçersiz olması
# 29                         Yanlış adres girişi
# 30                              Sipariş durumu
# 31                    Ödemenin tamamlanamaması
# 32                           Beden uyuşmazlığı
# 33                                Kupon hatası
# 34                                Kargo takibi
# 35                              Sipariş iptali
# 36                           Ürün tamir isteği
# 37                    E-posta aboneliği iptali
# 38                                Kargo takibi
# 39                       İade süreci gecikmesi

# %%
import os
def ortalama_hesapla(series1,series2,col):
    sent1 = series1
    sent2 = series2

    # Farklı olan satırların maskesi
    farkli_mask = sent1 != sent2

    # Farklı satırların indexleri
    farkli_indexler = sent1.index[farkli_mask].tolist()

    # Farklı satırların değerlerini görmek için
    farkli_degerler = [(i, sent1[i], sent2[i]) for i in farkli_indexler]

    # Benzerlik oranı
    same_cells = (sent1 == sent2).sum()
    total_cells = len(sent1)
    similarity_ratio = same_cells / total_cells * 100

    # Klasör adı
    klasor = "kontrol_sonuclari"

    # Klasör yoksa oluştur
    os.makedirs(klasor, exist_ok=True)

    print(f"{col} sütunu benzerlik: %{similarity_ratio:.2f}")

    # Dosya yolu -> klasör + dosya adı
    dosya_yolu = os.path.join(klasor, f"{col}Kontrol.txt")

    with open(dosya_yolu, "w", encoding="utf-8") as f:
        f.write("Farklı olan satırlar ve değerleri (index, manuel, tahmin):\n")
        for i, val1, val2 in farkli_degerler:
            satir = f"{i+1} {val1} ************** {val2}\n"
            f.write(satir)
    return similarity_ratio

# %%
elemanlar=["yanit_durumu","sentiment","tur","intent","intent_detay"]
sonuc=[]
for col in elemanlar:
        sonuc.append(ortalama_hesapla(dfLabels[col],df_yeni[col],col))
# Out:
# yanit_durumu sütunu benzerlik: %90.00
# sentiment sütunu benzerlik: %90.00
# tur sütunu benzerlik: %92.50
# intent sütunu benzerlik: %87.50
# intent_detay sütunu benzerlik: %90.00

# %%
import matplotlib.pyplot as plt


kategoriler = ["yanıt_durumu", "sentiment", "tur","intent","intent_detay"]
basari_oranlari = sonuc

plt.figure(figsize=(8, 6))
bars = plt.bar(
    kategoriler, 
    basari_oranlari, 
    color=["#36A2EB", "#FFCE56", "#FF6384", "#4BC0C0", "#9966FF"]
)
plt.xlabel("Kategori")
plt.ylabel("Başarı Oranı (%)")
plt.title("LLM Etiketleme Performansı")
plt.ylim(0, 100)

# Çubukların üzerine yüzde değerlerini ekle
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 2, f"{yval:.1f}%", ha="center", va="bottom")

plt.tight_layout()
plt.savefig("llm_basari_oranlari.png")
plt.show()

# %%
from ast import literal_eval
import csv

# CSV dosyalarını oku
try:
    true_df = pd.read_csv("manuel_labels.csv", quoting=csv.QUOTE_ALL, on_bad_lines="warn")
except FileNotFoundError:
    print("Hata: manuel_labels.csv dosyası bulunamadı. Lütfen dosya yolunu kontrol edin.")
    exit()
except pd.errors.ParserError as e:
    print(f"Hata: CSV ayrıştırma hatası: {e}")
    print("Lütfen manuel_labels_duzeltilmis.csv dosyasını kontrol edin (virgülle ayrılmış, tırnaklarla çevrili metinler).")
    exit()

try:
    llm_predictions_df = pd.read_csv("gpt-5-nano-out1.csv", quoting=csv.QUOTE_ALL, on_bad_lines="warn")
except FileNotFoundError:
    print("Hata: gpt-5-nano-out1.csv dosyası bulunamadı. Lütfen dosya yolunu kontrol edin.")
    exit()
except pd.errors.ParserError as e:
    print(f"Hata: CSV ayrıştırma hatası: {e}")
    print("Lütfen llm_predictions.csv dosyasını kontrol edin (virgülle ayrılmış, tırnaklarla çevrili metinler).")
    exit()

true_df["tum_mesajlar"]=df["tum_mesajlar"]
llm_predictions_df["tum_mesajlar"]=df["tum_mesajlar"]

# Sütun isimlerini kontrol et
print("Doğru veri CSV sütunları:", true_df.columns.tolist())
print("LLM tahmin CSV sütunları:", llm_predictions_df.columns.tolist())

#Gerekli sütunların varlığını kontrol et
required_columns =['sohbet_id', 'ilk_mesaj_tarihi', 'son_mesaj_tarihi', 'konusma_suresi_dakika', 'yanit_durumu', 'sentiment', 'tur', 'intent', 'intent_detay',"tum_mesajlar"]
if not all(col in true_df.columns for col in required_columns):
    print(f"Hata: Doğru veri CSV'sinde gerekli sütunlar eksik. Bulunan sütunlar: {true_df.columns.tolist()}")
    exit()
if not all(col in llm_predictions_df.columns for col in required_columns):
    print(f"Hata: LLM tahmin CSV'sinde gerekli sütunlar eksik. Bulunan sütunlar: {llm_predictions_df.columns.tolist()}")
    exit()


# JSON verisi oluştur
json_data = []
merged = true_df.merge(
    llm_predictions_df,
    on="sohbet_id",  # ortak sütunu seç
    suffixes=("_expected", "_predicted"),
    how="left"
)

# Sonra JSON üretimi
json_data=[]
for _, row in merged.iterrows():
    json_entry = {
    "sohbet_id": row["sohbet_id"], "tum_mesajlar": row["tum_mesajlar_expected"],
    "expected": {
        "yanit_durumu": row["yanit_durumu_expected"],
        "sentiment": row["sentiment_expected"],
        "tur": row["tur_expected"],
        "intent": row["intent_expected"],
        "intent_detay": row["intent_detay_expected"]
    },
    "llm_prediction": {
        "yanit_durumu": row["yanit_durumu_predicted"],
        "sentiment": row["sentiment_predicted"],
        "tur": row["tur_predicted"],
        "intent": row["intent_predicted"],
        "intent_detay": row["intent_detay_predicted"]
    }
}
    json_data.append(json_entry)
    if pd.isna(row["sentiment_predicted"]):
        print(f"Uyarı: {row['konusma']} için LLM tahmini bulunamadı.")

# JSON dosyasına kaydet
with open("llm_karsilastirma.json", "w", encoding="utf-8") as f:
    json.dump(json_data, f, ensure_ascii=False, indent=2)
# Out:
# Doğru veri CSV sütunları: ['sohbet_id', 'ilk_mesaj_tarihi', 'son_mesaj_tarihi', 'konusma_suresi_dakika', 'yanit_durumu', 'sentiment', 'tur', 'intent', 'intent_detay', 'tum_mesajlar']
# LLM tahmin CSV sütunları: ['sohbet_id', 'ilk_mesaj_tarihi', 'son_mesaj_tarihi', 'konusma_suresi_dakika', 'yanit_durumu', 'sentiment', 'tur', 'intent', 'intent_detay', 'tum_mesajlar']
